# %%
# Majority learner nao eh um algoritmo de ML, apenas classifica os dados de acordo com os padroes encontrados.
# Muito utilizado como metrica dos outros algoritmos

# %%
import Orange

# %%
base_credit = Orange.data.Table('/Users/fernandovieira/OneDrive/1. Educacao/INFO E ESTAT/IA Expert/ML-e-DS-com-Python-de-A-a-Z/Bases de dados/credit_data_regras.csv')

# %%
base_credit.domain
# Out:
# [income, age, loan | default]

# %%
# Treinamento
majority = Orange.classification.MajorityLearner()
previsoes = Orange.evaluation.testing.TestOnTestData(base_credit, base_credit, [majority]) # treinando e testando na mesma base de dados

# %%
# Previsoes
Orange.evaluation.CA(previsoes) # acuracia
# Out:
# array([0.8585])

# %%
for registro in base_credit:
    print(registro.get_class)
# Out:
# <bound method Instance.get_class of [66155.9, 59.017, 8106.53 | 0]>
# <bound method Instance.get_class of [34415.2, 48.1172, 6564.75 | 0]>
# <bound method Instance.get_class of [57317.2, 63.108, 8020.95 | 0]>
# <bound method Instance.get_class of [42709.5, 45.752, 6103.64 | 0]>
# <bound method Instance.get_class of [66952.7, 18.5843, 8770.1 | 1]>
# <bound method Instance.get_class of [24904.1, 57.4716, 15.4986 | 0]>
# <bound method Instance.get_class of [48430.4, 26.8091, 5722.58 | 0]>
# <bound method Instance.get_class of [24500.1, 32.8975, 2971 | 1]>
# <bound method Instance.get_class of [40654.9, 55.4969, 4755.83 | 0]>
# <bound method Instance.get_class of [25075.9, 39.7764, 1409.23 | 0]>
# <bound method Instance.get_class of [64131.4, 25.6796, 4351.03 | 0]>
# <bound method Instance.get_class of [59436.8, 60.4719, 9254.24 | 0]>
# <bound method Instance.get_class of [61050.3, 26.355, 5893.26 | 0]>
# <bound method Instance.get_class of [27268, 61.5768, 4759.79 | 0]>
# <bound method Instance.get_class of [63062, 39.2016, 1850.37 | 0]>
# <bound method Instance.get_class of [50501.7, -28.2184, 3977.29 | 0]>
# <bound method Instance.get_class of [43548.7, 39.5745, 3935.54 | 0]>
# <bound method Instance.get_class of [43378.2, 60.8483, 3277.74 | 0]>
# <bound method Instance.get_class of [20542.4, 61.6906, 3157.44 | 0]>
# <bound method Instance.get_class of [58887.4, 26.0761, 4965.52 | 0]>
# <bound method Instance.get_class of [23000.8, 31.7614, 1148.12 | 0]>
# <bound method Instance.get_class of [32197.6, -52.4233, 4244.06 | 0]>
# <bound method Instance.get_class of [23329.3, 48.577, 222.622 | 0]>
# <bound method Instance.get_class of [27845.8, 51.9706, 4959.92 | 0]>
# <bound method Instance.get_class of [65302, 48.8409, 5465.27 | 0]>
# <bound method Instance.get_class of [47451.6, 27.0317, 5361.28 | 0]>
# <bound method Instance.get_class of [63287, -36.497, 9595.29 | 0]>
# <bound method Instance.get_class of [45727.5, 55.8399, 6376.82 | 0]>
# <bound method Instance.get_class of [59417.8, ?, 2082.63 | 0]>
# <bound method Instance.get_class of [58842.9, 54.5109, 10871.2 | 0]>
# <bound method Instance.get_class of [48528.9, ?, 6155.78 | 0]>
# <bound method Instance.get_class of [23526.3, ?, 2862.01 | 0]>
# <bound method Instance.get_class of [67252.9, 38.1319, 4221.3 | 0]>
# <bound method Instance.get_class of [58886.9, 38.6615, 7271.55 | 0]>
# <bound method Instance.get_class of [57585, 36.672, 1728.42 | 0]>
# <bound method Instance.get_class of [26290, 20.6668, 341.147 | 0]>
# <bound method Instance.get_class of [25952.4, 58.185, 2109.2 | 0]>
# <bound method Instance.get_class of [32464.1, 50.225, 4326.71 | 0]>
# <bound method Instance.get_class of [60921.1, 18.8405, 968.836 | 0]>
# <bound method Instance.get_class of [26578.5, 32.676, 3489.84 | 1]>
# <bound method Instance.get_class of [66260.1, 32.8967, 7035.59 | 0]>
# <bound method Instance.get_class of [58787.5, 62.6413, 4167.79 | 0]>
# <bound method Instance.get_class of [62545.7, 49.0404, 4362.91 | 0]>
# <bound method Instance.get_class of [24382, 25.2523, 4227.02 | 1]>
# <bound method Instance.get_class of [67852.1, 47.3219, 5730.59 | 0]>
# <bound method Instance.get_class of [41725.6, 18.13, 1185.21 | 0]>
# <bound method Instance.get_class of [41897, 47.2507, 4892.21 | 0]>
# <bound method Instance.get_class of [44379.7, 50.0887, 1814.34 | 0]>
# <bound method Instance.get_class of [28416.9, 57.9287, 1788.97 | 0]>
# <bound method Instance.get_class of [68427.2, 46.3082, 1658.07 | 0]>
# <bound method Instance.get_class of [35975.8, 35.7087, 6610.37 | 0]>
# <bound method Instance.get_class of [57596.4, 29.2461, 3344.38 | 0]>
# <bound method Instance.get_class of [29681.9, 54.9593, 1745.87 | 0]>
# <bound method Instance.get_class of [51656.9, 47.7151, 7158.14 | 0]>
# <bound method Instance.get_class of [24912.8, 49.3664, 267.696 | 0]>
# <bound method Instance.get_class of [47761.8, 50.0982, 5549.8 | 0]>
# <bound method Instance.get_class of [22248.2, 23.4436, 4364.98 | 1]>
# <bound method Instance.get_class of [29724.5, 31.9685, 3075.35 | 0]>
# <bound method Instance.get_class of [52143.8, 20.8376, 2393.1 | 0]>
# <bound method Instance.get_class of [56577.7, 36.8478, 5947.42 | 0]>
# <bound method Instance.get_class of [37660.8, 53.7451, 2129.6 | 0]>
# <bound method Instance.get_class of [37403.8, 47.9441, 2044.05 | 0]>
# <bound method Instance.get_class of [31652.7, 62.0238, 5151.07 | 0]>
# <bound method Instance.get_class of [32727.7, 34.4749, 1087.92 | 0]>
# <bound method Instance.get_class of [69078.6, 25.1075, 4076.58 | 0]>
# <bound method Instance.get_class of [40622.2, 41.5272, 4949.9 | 0]>
# <bound method Instance.get_class of [37521, 60.5411, 8.01208 | 0]>
# <bound method Instance.get_class of [30735.8, 22.2421, 5946.82 | 1]>
# <bound method Instance.get_class of [24857.7, 21.5987, 2692.16 | 0]>
# <bound method Instance.get_class of [33180.2, 49.566, 4622 | 0]>
# <bound method Instance.get_class of [66628.3, 52.3839, 5992.89 | 0]>
# <bound method Instance.get_class of [38564.9, 21.2165, 5604.17 | 1]>
# <bound method Instance.get_class of [33704.5, 33.1831, 5898 | 1]>
# <bound method Instance.get_class of [57018.5, 44.8257, 3507.25 | 0]>
# <bound method Instance.get_class of [40526.9, 28.6064, 2119.98 | 0]>
# <bound method Instance.get_class of [50828, 51.0129, 1765.98 | 0]>
# <bound method Instance.get_class of [40775.8, 60.2888, 1922.61 | 0]>
# <bound method Instance.get_class of [55467.2, 56.8513, 9226.9 | 0]>
# <bound method Instance.get_class of [38789, 61.2293, 7650.66 | 0]>
# <bound method Instance.get_class of [58074.8, 50.0749, 7388.02 | 0]>
# <bound method Instance.get_class of [57814.1, 43.8309, 7252.12 | 0]>
# <bound method Instance.get_class of [45190.7, 53.8395, 7893.56 | 0]>
# <bound method Instance.get_class of [36801.9, 43.0279, 5406.34 | 0]>
# <bound method Instance.get_class of [68811.8, 24.0383, 4211.3 | 0]>
# <bound method Instance.get_class of [30483.3, 33.6564, 4514.01 | 1]>
# <bound method Instance.get_class of [44930.4, 19.7774, 7708.32 | 1]>
# <bound method Instance.get_class of [43671.5, 25.585, 8066.7 | 1]>
# <bound method Instance.get_class of [27612.9, 19.2124, 1513.62 | 0]>
# <bound method Instance.get_class of [53607.3, 27.5617, 2378.77 | 0]>
# <bound method Instance.get_class of [33036.7, 25.0634, 958.98 | 0]>
# <bound method Instance.get_class of [64275.8, 61.4409, 7520.03 | 0]>
# <bound method Instance.get_class of [30673.8, 59.3338, 383.108 | 0]>
# <bound method Instance.get_class of [58793.6, 56.4944, 4391.98 | 0]>
# <bound method Instance.get_class of [21053.5, 63.3794, 754.602 | 0]>
# <bound method Instance.get_class of [42095.4, 55.3662, 1183.7 | 0]>
# <bound method Instance.get_class of [50360.7, 28.8395, 4217.17 | 0]>
# <bound method Instance.get_class of [41970.7, 63.1699, 1622.32 | 0]>
# <bound method Instance.get_class of [51663.4, 63.7357, 4147.89 | 0]>
# <bound method Instance.get_class of [53601.8, 20.2406, 9601.38 | 1]>
# <bound method Instance.get_class of [43440, 24.1795, 6879.31 | 1]>
# <bound method Instance.get_class of [51461.1, 36.6516, 7292.26 | 0]>
# <bound method Instance.get_class of [41285.2, 47.9763, 2313.83 | 0]>
# <bound method Instance.get_class of [62895.7, 49.9226, 2001.28 | 0]>
# <bound method Instance.get_class of [57296.2, 25.7085, 10601.1 | 1]>
# <bound method Instance.get_class of [60844.1, 45.6552, 12072.3 | 0]>
# <bound method Instance.get_class of [47634.5, 44.2949, 141.704 | 0]>
# <bound method Instance.get_class of [23998.3, 29.91, 3928.3 | 1]>
# <bound method Instance.get_class of [63391.6, 34.7393, 190.889 | 0]>
# <bound method Instance.get_class of [21534.6, 44.315, 228.335 | 0]>
# <bound method Instance.get_class of [28255.7, 35.514, 2109.24 | 0]>
# <bound method Instance.get_class of [36496.1, 19.5157, 165.506 | 0]>
# <bound method Instance.get_class of [41631.7, 53.0477, 106.091 | 0]>
# <bound method Instance.get_class of [68762.4, 20.9912, 2796.75 | 0]>
# <bound method Instance.get_class of [30075.3, 29.2351, 2628.58 | 0]>
# <bound method Instance.get_class of [41302.7, 38.6606, 1379.91 | 0]>
# <bound method Instance.get_class of [39703.8, 47.4687, 2403.48 | 0]>
# <bound method Instance.get_class of [63161.1, 59.6751, 804.092 | 0]>
# <bound method Instance.get_class of [63062.1, 26.5858, 56.1662 | 0]>
# <bound method Instance.get_class of [34507.5, 38.5878, 1793.75 | 0]>
# <bound method Instance.get_class of [27954.7, 29.9045, 1627.04 | 0]>
# <bound method Instance.get_class of [37369.4, 35.3419, 3783.6 | 0]>
# <bound method Instance.get_class of [43912.1, 23.8219, 7757.14 | 1]>
# <bound method Instance.get_class of [22766.8, 29.3259, 1429.4 | 0]>
# <bound method Instance.get_class of [21603.3, 21.375, 178.334 | 0]>
# <bound method Instance.get_class of [61952.9, 18.4774, 3635.6 | 0]>
# <bound method Instance.get_class of [36116.4, 22.5359, 1494.98 | 0]>
# <bound method Instance.get_class of [26157.8, 22.8269, 2295.81 | 0]>
# <bound method Instance.get_class of [26458.4, 59.523, 552.398 | 0]>
# <bound method Instance.get_class of [69156.3, 53.4109, 7364.74 | 0]>
# <bound method Instance.get_class of [39441.4, 46.7539, 1034.76 | 0]>
# <bound method Instance.get_class of [60119.1, 45.077, 1810.96 | 0]>
# <bound method Instance.get_class of [55613.5, 24.3771, 4255.25 | 0]>
# <bound method Instance.get_class of [37049.4, 29.423, 6056.82 | 1]>
# <bound method Instance.get_class of [23122.1, 53.3095, 4263.49 | 0]>
# <bound method Instance.get_class of [48790.1, 32.4756, 5519.1 | 0]>
# <bound method Instance.get_class of [59132.7, 48.345, 4575.53 | 0]>
# <bound method Instance.get_class of [55305.6, 53.5823, 8176.71 | 0]>
# <bound method Instance.get_class of [26037.5, 24.7831, 3293.25 | 1]>
# <bound method Instance.get_class of [64899.8, 38.116, 4654.25 | 0]>
# <bound method Instance.get_class of [27089.1, 21.2077, 5029.49 | 1]>
# <bound method Instance.get_class of [45341.5, 22.5696, 6525.22 | 1]>
# <bound method Instance.get_class of [24865.8, 37.3098, 4439.12 | 0]>
# <bound method Instance.get_class of [28239.5, 26.1922, 4189.83 | 1]>
# <bound method Instance.get_class of [52730.1, 50.2378, 5706.33 | 0]>
# <bound method Instance.get_class of [28982.1, 39.0484, 2898.76 | 0]>
# <bound method Instance.get_class of [36221.3, 26.1015, 5094.67 | 1]>
# <bound method Instance.get_class of [33551.1, 58.8569, 4333.36 | 0]>
# <bound method Instance.get_class of [43891.4, 49.1538, 5792.91 | 0]>
# <bound method Instance.get_class of [45148.9, 60.525, 6455.39 | 0]>
# <bound method Instance.get_class of [58481, 40.8329, 5380.56 | 0]>
# <bound method Instance.get_class of [69579.9, 57.7562, 10868.2 | 0]>
# <bound method Instance.get_class of [52743.3, 44.0485, 2684.7 | 0]>
# <bound method Instance.get_class of [65635.7, 51.1677, 12701.6 | 0]>
# <bound method Instance.get_class of [34559.9, 29.1122, 3317.53 | 0]>
# <bound method Instance.get_class of [60218.5, 32.4719, 3157.96 | 0]>
# <bound method Instance.get_class of [51689.5, 46.1542, 9881.98 | 0]>
# <bound method Instance.get_class of [47541.6, 55.2346, 1611.22 | 0]>
# <bound method Instance.get_class of [62905.8, 27.9097, 11423.9 | 1]>
# <bound method Instance.get_class of [65632.6, 47.1058, 12498 | 0]>
# <bound method Instance.get_class of [31847.9, 41.4163, 2913.77 | 0]>
# <bound method Instance.get_class of [27947.4, 58.3485, 5514.12 | 0]>
# <bound method Instance.get_class of [62246.7, 31.0819, 406.721 | 0]>
# <bound method Instance.get_class of [40154.7, 60.5297, 6013.15 | 0]>
# <bound method Instance.get_class of [58627.6, 33.1157, 1215.65 | 0]>
# <bound method Instance.get_class of [33441.1, 27.8735, 5282.73 | 1]>
# <bound method Instance.get_class of [55603.8, 43.8395, 1411.13 | 0]>
# <bound method Instance.get_class of [31046.4, 29.2974, 4907.67 | 1]>
# <bound method Instance.get_class of [44708.1, 21.1088, 2390.85 | 0]>
# <bound method Instance.get_class of [23340.3, 42.8286, 2707.76 | 0]>
# <bound method Instance.get_class of [24830.2, 28.9702, 2046.69 | 0]>
# <bound method Instance.get_class of [31422.7, 53.8981, 1686.84 | 0]>
# <bound method Instance.get_class of [60477.2, 60.4021, 10711.7 | 0]>
# <bound method Instance.get_class of [26039, 49.3904, 2056.75 | 0]>
# <bound method Instance.get_class of [36186.8, 50.5068, 1130.74 | 0]>
# <bound method Instance.get_class of [39772.1, 43.7254, 5492.89 | 0]>
# <bound method Instance.get_class of [34730.2, 63.3762, 818.508 | 0]>
# <bound method Instance.get_class of [23118.5, 57.5811, 1746.94 | 0]>
# <bound method Instance.get_class of [50072.8, 33.0153, 8088.57 | 1]>
# <bound method Instance.get_class of [67465.1, 23.6111, 1802.62 | 0]>
# <bound method Instance.get_class of [38625.6, 19.63, 5836.56 | 1]>
# <bound method Instance.get_class of [45227.5, 26.7232, 5521.51 | 1]>
# <bound method Instance.get_class of [64901.9, 44.9388, 9589.83 | 0]>
# <bound method Instance.get_class of [40543.9, 51.4609, 6507.85 | 0]>
# <bound method Instance.get_class of [27793.3, 60.5169, 382.249 | 0]>
# <bound method Instance.get_class of [61167.8, 20.5836, 10396.6 | 1]>
# <bound method Instance.get_class of [64619.7, 26.0421, 9704.78 | 1]>
# <bound method Instance.get_class of [37593.8, 54.0104, 7274.33 | 0]>
# <bound method Instance.get_class of [35032.6, 56.7246, 135.932 | 0]>
# <bound method Instance.get_class of [58364.5, 55.5965, 5809.9 | 0]>
# <bound method Instance.get_class of [56945.8, 45.554, 6388.37 | 0]>
# <bound method Instance.get_class of [27204.8, 29.0721, 3827.89 | 1]>
# <bound method Instance.get_class of [21648.3, 52.587, 3558.53 | 0]>
# <bound method Instance.get_class of [31077.9, 44.2215, 4452.33 | 0]>
# <bound method Instance.get_class of [42522.9, 53.8687, 6790.85 | 0]>
# <bound method Instance.get_class of [31769.2, 44.7744, 1148.22 | 0]>
# <bound method Instance.get_class of [35556.8, 23.7774, 6361.97 | 1]>
# <bound method Instance.get_class of [52908.8, 53.6956, 9841.08 | 0]>
# <bound method Instance.get_class of [35045.1, 28.6533, 2382.47 | 0]>
# <bound method Instance.get_class of [44488.2, 33.4312, 2751.09 | 0]>
# <bound method Instance.get_class of [41679.9, 53.6699, 395.001 | 0]>
# <bound method Instance.get_class of [54619.9, 52.4244, 10780.3 | 0]>
# <bound method Instance.get_class of [38053.6, 26.2069, 6110.57 | 1]>
# <bound method Instance.get_class of [64718.7, 37.2765, 1485.08 | 0]>
# <bound method Instance.get_class of [43159.1, 62.4421, 4350.02 | 0]>
# <bound method Instance.get_class of [29445.5, 28.4457, 1758.88 | 0]>
# <bound method Instance.get_class of [25817.4, 37.9455, 4115.48 | 0]>
# <bound method Instance.get_class of [66356.9, 61.5248, 10725.5 | 0]>
# <bound method Instance.get_class of [56676.2, 46.679, 2278.55 | 0]>
# <bound method Instance.get_class of [61000, 48.6236, 2160.78 | 0]>
# <bound method Instance.get_class of [58906.3, 42.0493, 9290.58 | 0]>
# <bound method Instance.get_class of [49589.2, 42.7753, 2627.41 | 0]>
# <bound method Instance.get_class of [40141.6, 56.1514, 845.366 | 0]>
# <bound method Instance.get_class of [31659.7, 31.9282, 858.511 | 0]>
# <bound method Instance.get_class of [62658.2, 25.4632, 3343.37 | 0]>
# <bound method Instance.get_class of [39264.5, 37.0278, 5255.79 | 0]>
# <bound method Instance.get_class of [46643.1, 53.4051, 6440.86 | 0]>
# <bound method Instance.get_class of [30515.4, 20.1619, 415.24 | 0]>
# <bound method Instance.get_class of [65077.3, 50.9791, 11061.8 | 0]>
# <bound method Instance.get_class of [60871.9, 61.2601, 4844.17 | 0]>
# <bound method Instance.get_class of [25011.1, 36.2152, 3834.04 | 0]>
# <bound method Instance.get_class of [68407.2, 60.9376, 597.944 | 0]>
# <bound method Instance.get_class of [43727.4, 55.1926, 1170.56 | 0]>
# <bound method Instance.get_class of [45788.7, 41.2619, 5894.04 | 0]>
# <bound method Instance.get_class of [65705, 50.9284, 1969.79 | 0]>
# <bound method Instance.get_class of [32434.7, 41.3532, 2738.44 | 0]>
# <bound method Instance.get_class of [58121.7, 27.3018, 7531.1 | 1]>
# <bound method Instance.get_class of [62498.5, 31.9097, 3312.88 | 0]>
# <bound method Instance.get_class of [26090.7, 48.0785, 4255.63 | 0]>
# <bound method Instance.get_class of [64780.9, 20.2281, 8402.42 | 1]>
# <bound method Instance.get_class of [65588.4, 22.9182, 7879.74 | 1]>
# <bound method Instance.get_class of [65743.7, 52.3005, 7724.57 | 0]>
# <bound method Instance.get_class of [37164.5, 47.2955, 1445.8 | 0]>
# <bound method Instance.get_class of [65176.5, 48.9632, 2365.29 | 0]>
# <bound method Instance.get_class of [34615.5, 25.5144, 6476.76 | 1]>
# <bound method Instance.get_class of [59079.5, 58.6383, 10326.1 | 0]>
# <bound method Instance.get_class of [56267.2, 22.4861, 7329.24 | 1]>
# <bound method Instance.get_class of [34862.8, 54.9649, 6040.77 | 0]>
# <bound method Instance.get_class of [60521.4, 45.425, 8035.88 | 0]>
# <bound method Instance.get_class of [42276.8, 57.9307, 8055.31 | 0]>
# <bound method Instance.get_class of [38451.2, 63.4215, 3441.26 | 0]>
# <bound method Instance.get_class of [45985.1, 53.5339, 7382.06 | 0]>
# <bound method Instance.get_class of [51000.4, 27.803, 778.733 | 0]>
# <bound method Instance.get_class of [31523.1, 40.4462, 5174.57 | 0]>
# <bound method Instance.get_class of [28648.7, 18.397, 1870.93 | 0]>
# <bound method Instance.get_class of [27514.4, 21.8977, 3400.91 | 1]>
# <bound method Instance.get_class of [27441, 37.3991, 1455.05 | 0]>
# <bound method Instance.get_class of [67709.2, 50.4129, 5136.82 | 0]>
# <bound method Instance.get_class of [38600.7, 44.7228, 2749.08 | 0]>
# <bound method Instance.get_class of [30950.3, 26.3102, 5043.15 | 1]>
# <bound method Instance.get_class of [27083.8, 60.6667, 3286.21 | 0]>
# <bound method Instance.get_class of [21512.7, 24.7795, 2453.38 | 0]>
# <bound method Instance.get_class of [34796, 58.4879, 443.667 | 0]>
# <bound method Instance.get_class of [27089.4, 51.2942, 1851.31 | 0]>
# <bound method Instance.get_class of [25259.4, 39.7398, 4341.01 | 0]>
# <bound method Instance.get_class of [47007.3, 45.0198, 4069.4 | 0]>
# <bound method Instance.get_class of [20358.7, 53.6152, 1064.69 | 0]>
# <bound method Instance.get_class of [67900.2, 43.5143, 7902.74 | 0]>
# <bound method Instance.get_class of [54418.5, 55.2221, 5630.74 | 0]>
# <bound method Instance.get_class of [51288.6, 29.9207, 6536.97 | 1]>
# <bound method Instance.get_class of [28199.6, 36.6687, 3871.69 | 0]>
# <bound method Instance.get_class of [22199.6, 60.1048, 1498.39 | 0]>
# <bound method Instance.get_class of [50514.5, 57.3797, 2003.65 | 0]>
# <bound method Instance.get_class of [34414.2, 54.5302, 617.539 | 0]>
# <bound method Instance.get_class of [37633.1, 29.4214, 868.162 | 0]>
# <bound method Instance.get_class of [55235.5, 47.0053, 4910.55 | 0]>
# <bound method Instance.get_class of [45587.6, 62.0221, 8366.61 | 0]>
# <bound method Instance.get_class of [52757.8, 53.0822, 2321.21 | 0]>
# <bound method Instance.get_class of [41174.8, 52.3394, 2888.44 | 0]>
# <bound method Instance.get_class of [25685.5, 39.0092, 490.743 | 0]>
# <bound method Instance.get_class of [28145.3, 55.5476, 4805.97 | 0]>
# <bound method Instance.get_class of [52094.2, 40.8445, 495.021 | 0]>
# <bound method Instance.get_class of [33552.4, 25.1596, 6054.24 | 1]>
# <bound method Instance.get_class of [37400.9, 50.1085, 1693.14 | 0]>
# <bound method Instance.get_class of [21605.7, 23.2382, 2828.31 | 1]>
# <bound method Instance.get_class of [57562.9, 56.6006, 8508.84 | 0]>
# <bound method Instance.get_class of [62288.5, 25.6022, 10657.1 | 1]>
# <bound method Instance.get_class of [22767.3, 45.1233, 1205.79 | 0]>
# <bound method Instance.get_class of [20943, 19.8196, 4098.12 | 1]>
# <bound method Instance.get_class of [20622.9, 30.414, 3518.45 | 1]>
# <bound method Instance.get_class of [48436.7, 49.0278, 5851.41 | 0]>
# <bound method Instance.get_class of [27574.6, 57.6437, 1017.4 | 0]>
# <bound method Instance.get_class of [62889.4, 33.2457, 6525.15 | 0]>
# <bound method Instance.get_class of [37683.2, 55.5872, 7414.55 | 0]>
# <bound method Instance.get_class of [54974.5, 61.9842, 8922.2 | 0]>
# <bound method Instance.get_class of [56326.1, 40.4055, 4816.78 | 0]>
# <bound method Instance.get_class of [65670.9, 50.0047, 3950.87 | 0]>
# <bound method Instance.get_class of [50730.7, 41.9701, 1879.06 | 0]>
# <bound method Instance.get_class of [64184.9, 46.447, 1854.24 | 0]>
# <bound method Instance.get_class of [66179.3, 48.1208, 3646.94 | 0]>
# <bound method Instance.get_class of [24969.5, 45.121, 3595.5 | 0]>
# <bound method Instance.get_class of [54925.5, 40.8056, 554.488 | 0]>
# <bound method Instance.get_class of [67879.2, 43.5972, 10433.5 | 0]>
# <bound method Instance.get_class of [67787.5, 53.3623, 9607.5 | 0]>
# <bound method Instance.get_class of [31657.6, 37.7787, 1448.07 | 0]>
# <bound method Instance.get_class of [36559.1, 19.7162, 3030.27 | 0]>
# <bound method Instance.get_class of [57787.6, 22.6447, 6339.85 | 0]>
# <bound method Instance.get_class of [42521.7, 47.7043, 2661.61 | 0]>
# <bound method Instance.get_class of [51935.2, 21.4955, 5649.45 | 0]>
# <bound method Instance.get_class of [45677.9, 51.6931, 2966.25 | 0]>
# <bound method Instance.get_class of [51363.6, 21.022, 761.422 | 0]>
# <bound method Instance.get_class of [27218.6, 55.171, 4145 | 0]>
# <bound method Instance.get_class of [43677.6, 32.553, 6739.86 | 1]>
# <bound method Instance.get_class of [21533.6, 57.9017, 1971.55 | 0]>
# <bound method Instance.get_class of [28010.2, 55.3669, 3971.16 | 0]>
# <bound method Instance.get_class of [51589.3, 50.3135, 56.991 | 0]>
# <bound method Instance.get_class of [50481, 27.0804, 8831.18 | 1]>
# <bound method Instance.get_class of [43957.4, 21.1448, 5416.36 | 1]>
# <bound method Instance.get_class of [61878.3, 33.0064, 567.669 | 0]>
# <bound method Instance.get_class of [60153.3, 20.3009, 6472.35 | 0]>
# <bound method Instance.get_class of [33388.6, 62.0017, 4551.88 | 0]>
# <bound method Instance.get_class of [41310.4, 53.5769, 4481.16 | 0]>
# <bound method Instance.get_class of [25577, 51.9323, 1922.66 | 0]>
# <bound method Instance.get_class of [51455.1, 37.2857, 9447.12 | 0]>
# <bound method Instance.get_class of [48134.2, 47.9697, 2075.6 | 0]>
# <bound method Instance.get_class of [51348.5, 52.4367, 1507.89 | 0]>
# <bound method Instance.get_class of [20532.8, 54.6232, 1897.78 | 0]>
# <bound method Instance.get_class of [33297.2, 46.58, 3674.74 | 0]>
# <bound method Instance.get_class of [55858.5, 25.8665, 5630.44 | 0]>
# <bound method Instance.get_class of [43777.5, 20.0109, 3601.3 | 0]>
# <bound method Instance.get_class of [27789.5, 58.5191, 186.828 | 0]>
# <bound method Instance.get_class of [36132.4, 34.2943, 99.4496 | 0]>
# <bound method Instance.get_class of [20146, 21.2828, 839.839 | 0]>
# <bound method Instance.get_class of [63108.7, 43.1939, 5757.85 | 0]>
# <bound method Instance.get_class of [26581.6, 61.9534, 5090.39 | 0]>
# <bound method Instance.get_class of [62040.9, 62.0498, 7643.63 | 0]>
# <bound method Instance.get_class of [69958.7, 30.536, 8755.69 | 1]>
# <bound method Instance.get_class of [38082.5, 45.52, 4213.47 | 0]>
# <bound method Instance.get_class of [45183.1, 33.8956, 5953.45 | 1]>
# <bound method Instance.get_class of [36242.4, 39.4155, 5688.99 | 0]>
# <bound method Instance.get_class of [44527.3, 42.0901, 4588.47 | 0]>
# <bound method Instance.get_class of [40496.3, 20.1055, 4834.6 | 0]>
# <bound method Instance.get_class of [24698.7, 48.9126, 2427.65 | 0]>
# <bound method Instance.get_class of [60560.3, 49.7506, 1994.62 | 0]>
# <bound method Instance.get_class of [48018.2, 50.2041, 6120.09 | 0]>
# <bound method Instance.get_class of [30216.3, 26.5637, 2116.54 | 0]>
# <bound method Instance.get_class of [61742.2, 44.8726, 8068.32 | 0]>
# <bound method Instance.get_class of [47288.4, 62.4285, 4004.99 | 0]>
# <bound method Instance.get_class of [24658.9, 59.4365, 590.598 | 0]>
# <bound method Instance.get_class of [64644.3, 58.8407, 9848.17 | 0]>
# <bound method Instance.get_class of [57517.7, 52.4861, 4536.86 | 0]>
# <bound method Instance.get_class of [52945.5, 54.6319, 6262.01 | 0]>
# <bound method Instance.get_class of [36367, 47.1914, 371.041 | 0]>
# <bound method Instance.get_class of [62113.7, 27.8844, 11928.5 | 1]>
# <bound method Instance.get_class of [62279.5, 26.6665, 6801.41 | 0]>
# <bound method Instance.get_class of [61799.1, 56.958, 5619.22 | 0]>
# <bound method Instance.get_class of [50139.7, 30.2678, 7758.8 | 1]>
# <bound method Instance.get_class of [69566.7, 52.9671, 9875.04 | 0]>
# <bound method Instance.get_class of [44897.5, 51.3581, 5732.4 | 0]>
# <bound method Instance.get_class of [22572.3, 51.0162, 724.193 | 0]>
# <bound method Instance.get_class of [37123.1, 19.9467, 5659.51 | 1]>
# <bound method Instance.get_class of [68744.8, 60.7301, 5207.88 | 0]>
# <bound method Instance.get_class of [21081.2, 52.3828, 2395.17 | 0]>
# <bound method Instance.get_class of [58828.3, 32.4029, 5947.65 | 0]>
# <bound method Instance.get_class of [46706.5, 18.8303, 7084.26 | 1]>
# <bound method Instance.get_class of [32312.9, 28.1553, 228.331 | 0]>
# <bound method Instance.get_class of [60778.8, 43.013, 10021 | 0]>
# <bound method Instance.get_class of [30948, 42.7514, 3995.81 | 0]>
# <bound method Instance.get_class of [60122, 62.9096, 7189.35 | 0]>
# <bound method Instance.get_class of [43321.7, 32.2863, 743.867 | 0]>
# <bound method Instance.get_class of [47904.3, 40.0393, 6183.51 | 0]>
# <bound method Instance.get_class of [58597.4, 53.288, 2588.49 | 0]>
# <bound method Instance.get_class of [66091.9, 24.2041, 8743.51 | 1]>
# <bound method Instance.get_class of [47316.7, 27.0642, 1940.67 | 0]>
# <bound method Instance.get_class of [40872.6, 54.9481, 5312.49 | 0]>
# <bound method Instance.get_class of [35154.5, 52.8992, 4037.72 | 0]>
# <bound method Instance.get_class of [32222.8, 61.8106, 934.477 | 0]>
# <bound method Instance.get_class of [40447.7, 22.4929, 1072.19 | 0]>
# <bound method Instance.get_class of [48463.2, 50.5264, 8120.26 | 0]>
# <bound method Instance.get_class of [42843.1, 28.6318, 839.869 | 0]>
# <bound method Instance.get_class of [50310.4, 53.0387, 8361.72 | 0]>
# <bound method Instance.get_class of [57565.2, 37.7379, 5353.56 | 0]>
# <bound method Instance.get_class of [55066.2, 55.7392, 9332.7 | 0]>
# <bound method Instance.get_class of [46065.9, 52.8386, 4947.31 | 0]>
# <bound method Instance.get_class of [38309.6, 55.4291, 3545.72 | 0]>
# <bound method Instance.get_class of [54472.1, 59.246, 10836.4 | 0]>
# <bound method Instance.get_class of [58695.1, 29.7744, 1826.52 | 0]>
# <bound method Instance.get_class of [54748.9, 31.5969, 5438.09 | 0]>
# <bound method Instance.get_class of [46328.2, 56.8408, 7879.68 | 0]>
# <bound method Instance.get_class of [49633.3, 38.989, 7915.31 | 0]>
# <bound method Instance.get_class of [66339.8, 35.5919, 2350.89 | 0]>
# <bound method Instance.get_class of [62650.7, 33.4841, 6425.37 | 0]>
# <bound method Instance.get_class of [27646.8, 56.3117, 3132.15 | 0]>
# <bound method Instance.get_class of [21437.6, 45.7314, 2563.96 | 0]>
# <bound method Instance.get_class of [50648.2, 56.5173, 7110.76 | 0]>
# <bound method Instance.get_class of [29670.7, 53.5502, 2928.98 | 0]>
# <bound method Instance.get_class of [20258.5, 29.1155, 2767.84 | 1]>
# <bound method Instance.get_class of [34475.2, 42.3079, 3162.13 | 0]>
# <bound method Instance.get_class of [28926.4, 62.0653, 750.067 | 0]>
# <bound method Instance.get_class of [20660.7, 49.3639, 1756.04 | 0]>
# <bound method Instance.get_class of [24987.9, 49.0651, 3946.9 | 0]>
# <bound method Instance.get_class of [29672.6, 51.0198, 607.909 | 0]>
# <bound method Instance.get_class of [23241.6, 40.8478, 457.197 | 0]>
# <bound method Instance.get_class of [24217.2, 23.5108, 2104.38 | 0]>
# <bound method Instance.get_class of [65574.1, 23.513, 3031.25 | 0]>
# <bound method Instance.get_class of [55994.5, 31.1393, 680.62 | 0]>
# <bound method Instance.get_class of [67369.3, 57.6342, 2299.42 | 0]>
# <bound method Instance.get_class of [23305.8, 28.2175, 4521 | 1]>
# <bound method Instance.get_class of [35195.5, 49.6584, 2836.99 | 0]>
# <bound method Instance.get_class of [27135.1, 54.8365, 1387.25 | 0]>
# <bound method Instance.get_class of [24037.2, 23.3116, 2469.36 | 0]>
# <bound method Instance.get_class of [51625.3, 44.8088, 4592.25 | 0]>
# <bound method Instance.get_class of [50705.8, 53.2058, 1096.97 | 0]>
# <bound method Instance.get_class of [58079.2, 18.663, 11540 | 1]>
# <bound method Instance.get_class of [62192.5, 46.0508, 1863.89 | 0]>
# <bound method Instance.get_class of [62553.7, 63.925, 4641.7 | 0]>
# <bound method Instance.get_class of [68148, 22.9844, 12307.6 | 1]>
# <bound method Instance.get_class of [27619.7, 47.5405, 2774.83 | 0]>
# <bound method Instance.get_class of [65330.2, 28.59, 4030.8 | 0]>
# <bound method Instance.get_class of [26680.1, 47.7617, 1671.18 | 0]>
# <bound method Instance.get_class of [46104.6, 51.0564, 2342.47 | 0]>
# <bound method Instance.get_class of [44904.6, 44.2067, 4953.77 | 0]>
# <bound method Instance.get_class of [52934.6, 50.403, 3248.63 | 0]>
# <bound method Instance.get_class of [43509.8, 18.0753, 7363.04 | 1]>
# <bound method Instance.get_class of [22118.4, 63.0159, 3928.12 | 0]>
# <bound method Instance.get_class of [56275.4, 30.2499, 2224.88 | 0]>
# <bound method Instance.get_class of [48631, 27.0217, 5862.83 | 1]>
# <bound method Instance.get_class of [64272.7, 37.778, 4929.88 | 0]>
# <bound method Instance.get_class of [24349, 53.7525, 3890.47 | 0]>
# <bound method Instance.get_class of [34332.3, 36.5014, 1225.72 | 0]>
# <bound method Instance.get_class of [64940.2, 43.941, 8196.93 | 0]>
# <bound method Instance.get_class of [30595.7, 40.9115, 3495.07 | 0]>
# <bound method Instance.get_class of [53422.2, 28.1885, 7441.76 | 1]>
# <bound method Instance.get_class of [69995.7, 52.7197, 2084.37 | 0]>
# <bound method Instance.get_class of [48270.8, 45.3059, 6232.28 | 0]>
# <bound method Instance.get_class of [27028.2, 48.1096, 331.364 | 0]>
# <bound method Instance.get_class of [23519.9, 34.3937, 2368.38 | 0]>
# <bound method Instance.get_class of [37302.1, 35.0154, 2366.17 | 0]>
# <bound method Instance.get_class of [55601.3, 18.843, 10533.5 | 1]>
# <bound method Instance.get_class of [62678.6, 25.8394, 333.441 | 0]>
# <bound method Instance.get_class of [41602.4, 25.2599, 7005.08 | 1]>
# <bound method Instance.get_class of [27533, 46.7659, 1551.42 | 0]>
# <bound method Instance.get_class of [30594.2, 50.0438, 118.342 | 0]>
# <bound method Instance.get_class of [47846.9, 24.4184, 3713.26 | 0]>
# <bound method Instance.get_class of [55273.3, 25.4164, 10283 | 1]>
# <bound method Instance.get_class of [23086.3, 24.85, 1256.4 | 0]>
# <bound method Instance.get_class of [29621.3, 32.4554, 5575.25 | 1]>
# <bound method Instance.get_class of [47533.9, 39.9552, 6637.77 | 0]>
# <bound method Instance.get_class of [62519.2, 44.41, 2324.55 | 0]>
# <bound method Instance.get_class of [50879, 44.9651, 3257.01 | 0]>
# <bound method Instance.get_class of [58581, 56.627, 4317.72 | 0]>
# <bound method Instance.get_class of [69445.6, 28.8183, 10643.4 | 1]>
# <bound method Instance.get_class of [60929.2, 60.0588, 11146.1 | 0]>
# <bound method Instance.get_class of [35496.7, 47.0027, 168.055 | 0]>
# <bound method Instance.get_class of [33572.4, 57.4422, 3369.38 | 0]>
# <bound method Instance.get_class of [55306.9, 20.1403, 5272.54 | 0]>
# <bound method Instance.get_class of [34141.9, 47.1511, 3371.66 | 0]>
# <bound method Instance.get_class of [40453.9, 20.7099, 890.94 | 0]>
# <bound method Instance.get_class of [69088.8, 53.9356, 11246.5 | 0]>
# <bound method Instance.get_class of [30885.7, 55.1508, 5216.35 | 0]>
# <bound method Instance.get_class of [58683.2, 24.845, 271.734 | 0]>
# <bound method Instance.get_class of [60675.8, 39.9639, 11617.7 | 0]>
# <bound method Instance.get_class of [68460.7, 35.7756, 949.957 | 0]>
# <bound method Instance.get_class of [63653.8, 27.5154, 8866.53 | 1]>
# <bound method Instance.get_class of [42522.6, 18.3261, 5036.26 | 0]>
# <bound method Instance.get_class of [54140.4, 30.8889, 7896.22 | 1]>
# <bound method Instance.get_class of [47548.4, 47.8391, 6153.94 | 0]>
# <bound method Instance.get_class of [24114, 52.3358, 3900.83 | 0]>
# <bound method Instance.get_class of [20686.2, 33.2805, 3052.58 | 1]>
# <bound method Instance.get_class of [21412.3, 26.3827, 2639.71 | 1]>
# <bound method Instance.get_class of [69391.1, 63.8007, 2550.27 | 0]>
# <bound method Instance.get_class of [32319.3, 42.932, 2733.42 | 0]>
# <bound method Instance.get_class of [52862.9, 47.3314, 9754.15 | 0]>
# <bound method Instance.get_class of [48383.3, 39.7047, 2763.26 | 0]>
# <bound method Instance.get_class of [36430.5, 38.2274, 5855.19 | 0]>
# <bound method Instance.get_class of [44268.9, 27.9332, 6043.14 | 1]>
# <bound method Instance.get_class of [63806.3, 56.6322, 114.5 | 0]>
# <bound method Instance.get_class of [46195.8, 32.4136, 927.068 | 0]>
# <bound method Instance.get_class of [23743.2, 42.7346, 3254.75 | 0]>
# <bound method Instance.get_class of [22089.8, 21.2967, 2584.02 | 0]>
# <bound method Instance.get_class of [54707.3, 44.2379, 10255.2 | 0]>
# <bound method Instance.get_class of [23203.6, 58.5689, 749.145 | 0]>
# <bound method Instance.get_class of [25342.3, 40.3611, 871.53 | 0]>
# <bound method Instance.get_class of [31645.6, 32.1633, 5193.84 | 1]>
# <bound method Instance.get_class of [32306.8, 21.9063, 3603.36 | 0]>
# <bound method Instance.get_class of [61262.8, 49.413, 5564.16 | 0]>
# <bound method Instance.get_class of [26388.7, 19.3715, 1191.33 | 0]>
# <bound method Instance.get_class of [53009.4, 36.0745, 3589.25 | 0]>
# <bound method Instance.get_class of [58163.5, 58.7475, 2237.93 | 0]>
# <bound method Instance.get_class of [38665, 55.1259, 6152 | 0]>
# <bound method Instance.get_class of [25289, 53.3427, 3701.54 | 0]>
# <bound method Instance.get_class of [66049.9, 29.3158, 13172.7 | 1]>
# <bound method Instance.get_class of [56283, 62.3699, 8215.56 | 0]>
# <bound method Instance.get_class of [35778.6, 30.6282, 5544.65 | 1]>
# <bound method Instance.get_class of [29174.2, 18.5286, 665.577 | 0]>
# <bound method Instance.get_class of [55934.4, 60.7552, 5643.18 | 0]>
# <bound method Instance.get_class of [32256.9, 20.0964, 2809.32 | 0]>
# <bound method Instance.get_class of [68052.8, 28.7588, 1415.72 | 0]>
# <bound method Instance.get_class of [26957.1, 55.2649, 4172.99 | 0]>
# <bound method Instance.get_class of [48685, 32.5333, 9698.58 | 1]>
# <bound method Instance.get_class of [38288.1, 28.7354, 1723.4 | 0]>
# <bound method Instance.get_class of [42468, 28.6258, 1902.27 | 0]>
# <bound method Instance.get_class of [55377.8, 46.9182, 6882.87 | 0]>
# <bound method Instance.get_class of [54231.7, 21.2742, 10156.1 | 1]>
# <bound method Instance.get_class of [53283.3, 49.0047, 4065.22 | 0]>
# <bound method Instance.get_class of [52534.8, 47.1836, 3810.13 | 0]>
# <bound method Instance.get_class of [47847.5, 26.6518, 8494.02 | 1]>
# <bound method Instance.get_class of [59998.3, 54.3089, 4659.54 | 0]>
# <bound method Instance.get_class of [58684.5, 31.7323, 5415.82 | 0]>
# <bound method Instance.get_class of [49114.8, 61.4815, 6388.85 | 0]>
# <bound method Instance.get_class of [57179.4, 21.3731, 2991.97 | 0]>
# <bound method Instance.get_class of [69395.1, 23.9514, 11047.7 | 1]>
# <bound method Instance.get_class of [43963.7, 41.5538, 4481.44 | 0]>
# <bound method Instance.get_class of [66326.5, 40.9803, 5602.16 | 0]>
# <bound method Instance.get_class of [35886.7, 34.6683, 843.749 | 0]>
# <bound method Instance.get_class of [35578.2, 42.3946, 3640.85 | 0]>
# <bound method Instance.get_class of [48689, 36.5631, 3859.47 | 0]>
# <bound method Instance.get_class of [56510.8, 47.3083, 9255.44 | 0]>
# <bound method Instance.get_class of [50275.9, 41.8198, 5541.82 | 0]>
# <bound method Instance.get_class of [56665.5, 61.6451, 11159.8 | 0]>
# <bound method Instance.get_class of [42912.1, 60.5822, 4550.12 | 0]>
# <bound method Instance.get_class of [22169.7, 36.9707, 947.2 | 0]>
# <bound method Instance.get_class of [35919.8, 27.3041, 1227.11 | 0]>
# <bound method Instance.get_class of [61987.7, 27.6311, 2618.24 | 0]>
# <bound method Instance.get_class of [30044.7, 49.7741, 1428.44 | 0]>
# <bound method Instance.get_class of [61528.3, 55.903, 10897.9 | 0]>
# <bound method Instance.get_class of [31196.5, 47.1788, 987.262 | 0]>
# <bound method Instance.get_class of [66004, 33.0735, 11207.5 | 1]>
# <bound method Instance.get_class of [56960.7, 25.518, 4856.48 | 0]>
# <bound method Instance.get_class of [41315.1, 57.5201, 1378.91 | 0]>
# <bound method Instance.get_class of [64913.3, 26.7663, 9781.33 | 1]>
# <bound method Instance.get_class of [32804.9, 62.2944, 4961.26 | 0]>
# <bound method Instance.get_class of [25789.2, 26.4942, 2410.28 | 0]>
# <bound method Instance.get_class of [31908.4, 38.2525, 1857.46 | 0]>
# <bound method Instance.get_class of [56050.3, 23.9738, 6870.84 | 1]>
# <bound method Instance.get_class of [66505.8, 25.6182, 6571.2 | 0]>
# <bound method Instance.get_class of [57504.1, 55.7171, 8107.27 | 0]>
# <bound method Instance.get_class of [44619.1, 59.8525, 2474.98 | 0]>
# <bound method Instance.get_class of [21158.9, 54.3039, 3562.31 | 0]>
# <bound method Instance.get_class of [22765.2, 20.5874, 540.618 | 0]>
# <bound method Instance.get_class of [25052.8, 45.574, 3367.7 | 0]>
# <bound method Instance.get_class of [61006.1, 54.1813, 5850.77 | 0]>
# <bound method Instance.get_class of [62321.2, 45.8903, 10649.1 | 0]>
# <bound method Instance.get_class of [49604.5, 51.944, 7045.92 | 0]>
# <bound method Instance.get_class of [48433.4, 28.532, 789.633 | 0]>
# <bound method Instance.get_class of [57590.3, 19.4971, 7676.31 | 1]>
# <bound method Instance.get_class of [62691.7, 25.0644, 8244.75 | 1]>
# <bound method Instance.get_class of [51121.7, 58.5272, 6471.63 | 0]>
# <bound method Instance.get_class of [22516.5, 55.5189, 4267.45 | 0]>
# <bound method Instance.get_class of [60857.2, 37.3943, 10486.7 | 0]>
# <bound method Instance.get_class of [62908.4, 51.1468, 3213.9 | 0]>
# <bound method Instance.get_class of [49665.6, 50.3192, 2713.89 | 0]>
# <bound method Instance.get_class of [65322.8, 41.4542, 2739.72 | 0]>
# <bound method Instance.get_class of [20598.9, 35.7712, 3872.4 | 0]>
# <bound method Instance.get_class of [55476.7, 52.0892, 4733.51 | 0]>
# <bound method Instance.get_class of [26218.5, 18.4162, 3343.82 | 1]>
# <bound method Instance.get_class of [40794.9, 38.0405, 6519.44 | 0]>
# <bound method Instance.get_class of [53719.7, 42.8901, 1670.74 | 0]>
# <bound method Instance.get_class of [20715.5, 27.5303, 369.528 | 0]>
# <bound method Instance.get_class of [57163.9, 53.5448, 577.531 | 0]>
# <bound method Instance.get_class of [33751.2, 25.3019, 6494.18 | 1]>
# <bound method Instance.get_class of [44832.6, 32.1783, 1256.25 | 0]>
# <bound method Instance.get_class of [51035.6, 58.995, 2889.88 | 0]>
# <bound method Instance.get_class of [53493.5, 21.8747, 5030.83 | 0]>
# <bound method Instance.get_class of [58205.7, 56.8378, 10035.6 | 0]>
# <bound method Instance.get_class of [47439.9, 22.3484, 7896.36 | 1]>
# <bound method Instance.get_class of [47586.2, 42.275, 3343.06 | 0]>
# <bound method Instance.get_class of [26100.9, 62.3192, 960.137 | 0]>
# <bound method Instance.get_class of [45326.4, 59.3625, 5142.11 | 0]>
# <bound method Instance.get_class of [24391.8, 47.0351, 2198.14 | 0]>
# <bound method Instance.get_class of [53741.4, 49.7294, 6513.15 | 0]>
# <bound method Instance.get_class of [40053.7, 27.9385, 44.5272 | 0]>
# <bound method Instance.get_class of [53033.9, 38.4576, 10427.5 | 0]>
# <bound method Instance.get_class of [25176.5, 53.5434, 3064.72 | 0]>
# <bound method Instance.get_class of [31210.8, 54.1049, 3853.09 | 0]>
# <bound method Instance.get_class of [23532.3, 59.6337, 1077.84 | 0]>
# <bound method Instance.get_class of [63776.8, 43.8107, 6697.97 | 0]>
# <bound method Instance.get_class of [52278.8, 45.929, 4269.14 | 0]>
# <bound method Instance.get_class of [56015.8, 32.5093, 2275.76 | 0]>
# <bound method Instance.get_class of [56110.9, 62.8294, 9351.01 | 0]>
# <bound method Instance.get_class of [57856.8, 33.6822, 8824.16 | 1]>
# <bound method Instance.get_class of [30187.1, 28.1551, 4462.82 | 1]>
# <bound method Instance.get_class of [30786.9, 47.0681, 3563.32 | 0]>
# <bound method Instance.get_class of [22279.3, 58.9073, 3141.34 | 0]>
# <bound method Instance.get_class of [42476.3, 46.4382, 8334.18 | 0]>
# <bound method Instance.get_class of [58147.8, 34.0586, 3951.19 | 0]>
# <bound method Instance.get_class of [36266.2, 55.5424, 3206.93 | 0]>
# <bound method Instance.get_class of [39045.5, 27.4332, 1165.49 | 0]>
# <bound method Instance.get_class of [64467.8, 63.4006, 521.576 | 0]>
# <bound method Instance.get_class of [36594.8, 60.9126, 3492.33 | 0]>
# <bound method Instance.get_class of [58797.8, 53.4034, 8892.96 | 0]>
# <bound method Instance.get_class of [66653.3, 19.8871, 5180.71 | 0]>
# <bound method Instance.get_class of [48271.5, 21.6623, 6077.68 | 1]>
# <bound method Instance.get_class of [30991.4, 34.01, 4589.27 | 1]>
# <bound method Instance.get_class of [45446.5, 19.3047, 8474.98 | 1]>
# <bound method Instance.get_class of [37142.7, 50.303, 161.238 | 0]>
# <bound method Instance.get_class of [58320.8, 20.2576, 10033.5 | 1]>
# <bound method Instance.get_class of [24825.5, 54.8175, 3650.2 | 0]>
# <bound method Instance.get_class of [20511.4, 27.1963, 931.79 | 0]>
# <bound method Instance.get_class of [48326.3, 35.6522, 7168.71 | 0]>
# <bound method Instance.get_class of [55441.4, 48.0586, 10768.7 | 0]>
# <bound method Instance.get_class of [60496.9, 33.9457, 1115.15 | 0]>
# <bound method Instance.get_class of [25296.2, 44.3561, 1320.46 | 0]>
# <bound method Instance.get_class of [50414.3, 56.194, 2468.17 | 0]>
# <bound method Instance.get_class of [67984, 27.4653, 1642.97 | 0]>
# <bound method Instance.get_class of [50382.4, 57.0969, 9183.84 | 0]>
# <bound method Instance.get_class of [49413.3, 18.6479, 2554.04 | 0]>
# <bound method Instance.get_class of [61464.8, 36.4083, 5099.09 | 0]>
# <bound method Instance.get_class of [53784, 24.3936, 2761.85 | 0]>
# <bound method Instance.get_class of [35993.3, 41.875, 901.928 | 0]>
# <bound method Instance.get_class of [63402, 47.2234, 7530.77 | 0]>
# <bound method Instance.get_class of [40485, 39.2814, 1093.68 | 0]>
# <bound method Instance.get_class of [26168, 41.9412, 3040.98 | 0]>
# <bound method Instance.get_class of [60044.3, 61.3127, 6823.43 | 0]>
# <bound method Instance.get_class of [23984.6, 51.1413, 4622.28 | 0]>
# <bound method Instance.get_class of [40359.7, 32.245, 1783.7 | 0]>
# <bound method Instance.get_class of [33583.9, 62.1308, 1251.87 | 0]>
# <bound method Instance.get_class of [68038.8, 62.9481, 10108.8 | 0]>
# <bound method Instance.get_class of [45652.1, 53.6743, 5408.21 | 0]>
# <bound method Instance.get_class of [34399.2, 31.7649, 6019.83 | 1]>
# <bound method Instance.get_class of [57628.4, 23.9866, 5021.64 | 0]>
# <bound method Instance.get_class of [24294.7, 22.2631, 4360.05 | 1]>
# <bound method Instance.get_class of [52218.9, 37.5428, 9792.09 | 0]>
# <bound method Instance.get_class of [50061.8, 55.361, 6145.13 | 0]>
# <bound method Instance.get_class of [49352.3, 57.5422, 3362.77 | 0]>
# <bound method Instance.get_class of [21087.4, 49.3106, 3353.69 | 0]>
# <bound method Instance.get_class of [23812.3, 42.7656, 2716.66 | 0]>
# <bound method Instance.get_class of [49395.2, 41.0849, 5927.57 | 0]>
# <bound method Instance.get_class of [33338.9, 46.5985, 2929.85 | 0]>
# <bound method Instance.get_class of [29668.3, 38.6837, 2042.44 | 0]>
# <bound method Instance.get_class of [45936.6, 41.994, 8525.23 | 0]>
# <bound method Instance.get_class of [55948.1, 40.303, 8569.22 | 0]>
# <bound method Instance.get_class of [53239.5, 63.5151, 4606.16 | 0]>
# <bound method Instance.get_class of [43694, 49.515, 5049.64 | 0]>
# <bound method Instance.get_class of [24078.1, 38.4916, 3276.14 | 0]>
# <bound method Instance.get_class of [50258.6, 22.5428, 1086.25 | 0]>
# <bound method Instance.get_class of [41816.7, 48.9172, 4534.58 | 0]>
# <bound method Instance.get_class of [36892.7, 54.4484, 6463.65 | 0]>
# <bound method Instance.get_class of [23886.6, 34.443, 4440.42 | 1]>
# <bound method Instance.get_class of [48757.8, 23.076, 1833.58 | 0]>
# <bound method Instance.get_class of [34601.7, 33.8505, 2430.1 | 0]>
# <bound method Instance.get_class of [52986, 50.4238, 4928.61 | 0]>
# <bound method Instance.get_class of [50741, 21.7214, 784.577 | 0]>
# <bound method Instance.get_class of [53097, 36.3501, 2663.05 | 0]>
# <bound method Instance.get_class of [38500, 53.9307, 7571.68 | 0]>
# <bound method Instance.get_class of [41004.3, 55.8491, 1016.14 | 0]>
# <bound method Instance.get_class of [63585.4, 49.3399, 1594.97 | 0]>
# <bound method Instance.get_class of [31823.7, 30.9836, 2290.43 | 0]>
# <bound method Instance.get_class of [26242.6, 32.5968, 1801.23 | 0]>
# <bound method Instance.get_class of [63531.2, 19.3291, 6917.51 | 0]>
# <bound method Instance.get_class of [64751.1, 53.6382, 2289.85 | 0]>
# <bound method Instance.get_class of [31091.3, 50.8955, 4071.08 | 0]>
# <bound method Instance.get_class of [66871.3, 62.6894, 3614.27 | 0]>
# <bound method Instance.get_class of [25098.7, 51.6471, 2611.85 | 0]>
# <bound method Instance.get_class of [33720.6, 47.2466, 1365.95 | 0]>
# <bound method Instance.get_class of [28182.5, 25.5296, 2285.96 | 0]>
# <bound method Instance.get_class of [27334.6, 42.6712, 2963.79 | 0]>
# <bound method Instance.get_class of [68694.8, 23.0814, 12731.9 | 1]>
# <bound method Instance.get_class of [46195.6, 26.6272, 2888.63 | 0]>
# <bound method Instance.get_class of [34488.2, 27.1315, 2156.31 | 0]>
# <bound method Instance.get_class of [57827.7, 23.973, 10816.8 | 1]>
# <bound method Instance.get_class of [20346.5, 35.7161, 656.033 | 0]>
# <bound method Instance.get_class of [60481, 53.4287, 3216.09 | 0]>
# <bound method Instance.get_class of [51915.7, 44.1091, 2282.91 | 0]>
# <bound method Instance.get_class of [54625.5, 31.6965, 8619.75 | 1]>
# <bound method Instance.get_class of [48305.4, 55.2125, 4833.48 | 0]>
# <bound method Instance.get_class of [28578, 21.4202, 1639.23 | 0]>
# <bound method Instance.get_class of [53400.8, 58.0817, 10418.2 | 0]>
# <bound method Instance.get_class of [43414.5, 44.4534, 7170.95 | 0]>
# <bound method Instance.get_class of [47526.2, 57.2196, 8957.33 | 0]>
# <bound method Instance.get_class of [46082.1, 55.1585, 2921.24 | 0]>
# <bound method Instance.get_class of [32195.6, 62.2017, 4980.01 | 0]>
# <bound method Instance.get_class of [49067.1, 60.5446, 7258.97 | 0]>
# <bound method Instance.get_class of [21293.5, 42.4049, 1368.69 | 0]>
# <bound method Instance.get_class of [52100.9, 23.1814, 4767.28 | 0]>
# <bound method Instance.get_class of [48334.4, 53.3678, 2234.44 | 0]>
# <bound method Instance.get_class of [58507.6, 48.9774, 694.135 | 0]>
# <bound method Instance.get_class of [27521, 35.0866, 2699.85 | 0]>
# <bound method Instance.get_class of [63914.2, 26.3497, 139.315 | 0]>
# <bound method Instance.get_class of [28598.8, 52.5337, 524.201 | 0]>
# <bound method Instance.get_class of [23298.5, 48.6515, 1741.18 | 0]>
# <bound method Instance.get_class of [35697.6, 51.3882, 2907.96 | 0]>
# <bound method Instance.get_class of [40376.2, 38.9213, 3901.94 | 0]>
# <bound method Instance.get_class of [56535, 27.8079, 2161.08 | 0]>
# <bound method Instance.get_class of [36088.9, 41.7178, 6222.42 | 0]>
# <bound method Instance.get_class of [34158.6, 29.4211, 2911.41 | 0]>
# <bound method Instance.get_class of [29732.1, 38.8767, 3485.02 | 0]>
# <bound method Instance.get_class of [41736.2, 34.5965, 7602.61 | 1]>
# <bound method Instance.get_class of [42236.5, 24.6867, 4749.07 | 0]>
# <bound method Instance.get_class of [28796.9, 44.6286, 706.229 | 0]>
# <bound method Instance.get_class of [55097.4, 33.9294, 9342.48 | 1]>
# <bound method Instance.get_class of [40916.6, 48.3197, 5219.8 | 0]>
# <bound method Instance.get_class of [20908.3, 28.8185, 3133.62 | 1]>
# <bound method Instance.get_class of [57999.8, 62.7701, 859.589 | 0]>
# <bound method Instance.get_class of [57746.6, 63.6253, 727.195 | 0]>
# <bound method Instance.get_class of [55116.2, 41.4689, 10284.6 | 0]>
# <bound method Instance.get_class of [57765.5, 43.8873, 5445.22 | 0]>
# <bound method Instance.get_class of [45201, 43.9054, 7335.96 | 0]>
# <bound method Instance.get_class of [42435.2, 51.4895, 2766.28 | 0]>
# <bound method Instance.get_class of [46365.6, 41.8526, 5443.28 | 0]>
# <bound method Instance.get_class of [57187.7, 59.4719, 9390.67 | 0]>
# <bound method Instance.get_class of [66539.9, 57.7056, 12129.1 | 0]>
# <bound method Instance.get_class of [25244.7, 53.379, 1279 | 0]>
# <bound method Instance.get_class of [54780.3, 61.389, 8134.22 | 0]>
# <bound method Instance.get_class of [59253.1, 36.9204, 7327.28 | 0]>
# <bound method Instance.get_class of [48540.3, 21.2392, 1012.93 | 0]>
# <bound method Instance.get_class of [30415.1, 22.9836, 4362.08 | 1]>
# <bound method Instance.get_class of [48768.7, 25.925, 500.599 | 0]>
# <bound method Instance.get_class of [52299.2, 18.3097, 7880.69 | 1]>
# <bound method Instance.get_class of [42242.5, 34.2208, 2070.38 | 0]>
# ...
# <bound method Instance.get_class of [51903.5, 59.7627, 8807.87 | 0]>
# <bound method Instance.get_class of [64398.1, 35.5975, 1674.91 | 0]>
# <bound method Instance.get_class of [41089.5, 57.6274, 997.184 | 0]>
# <bound method Instance.get_class of [36727.6, 24.5973, 794.557 | 0]>
# <bound method Instance.get_class of [38163.4, 63.2517, 454.308 | 0]>
# <bound method Instance.get_class of [35949.9, 56.7387, 3680.18 | 0]>
# <bound method Instance.get_class of [44979.8, 32.5319, 6045.09 | 1]>
# <bound method Instance.get_class of [48211.6, 30.5573, 2606.12 | 0]>
# <bound method Instance.get_class of [28267.1, 54.6463, 965.373 | 0]>
# <bound method Instance.get_class of [33816.2, 60.2482, 5265.74 | 0]>
# <bound method Instance.get_class of [33079, 36.3272, 6278.32 | 0]>
# <bound method Instance.get_class of [36019.8, 42.8457, 2987.96 | 0]>
# <bound method Instance.get_class of [34238.5, 63.4342, 6002.94 | 0]>
# <bound method Instance.get_class of [62064.5, 22.8259, 2972.38 | 0]>
# <bound method Instance.get_class of [44867.6, 55.8128, 366.101 | 0]>
# <bound method Instance.get_class of [37162.9, 28.8766, 3110.53 | 0]>
# <bound method Instance.get_class of [65680.9, 62.7794, 8838.23 | 0]>
# <bound method Instance.get_class of [58772.9, 46.505, 7048.01 | 0]>
# <bound method Instance.get_class of [32435.2, 43.0663, 5685.41 | 0]>
# <bound method Instance.get_class of [58028.2, 50.0955, 5753.9 | 0]>
# <bound method Instance.get_class of [60595.3, 62.2207, 4534.49 | 0]>
# <bound method Instance.get_class of [36565.8, 19.8994, 1888.33 | 0]>
# <bound method Instance.get_class of [20742.7, 61.5984, 2295.82 | 0]>
# <bound method Instance.get_class of [46666.6, 18.7456, 7677.82 | 1]>
# <bound method Instance.get_class of [32203.6, 61.1676, 838.021 | 0]>
# <bound method Instance.get_class of [36535.3, 29.8749, 271.725 | 0]>
# <bound method Instance.get_class of [28163.3, 58.0035, 2121.15 | 0]>
# <bound method Instance.get_class of [39019.4, 31.7927, 3196.56 | 0]>
# <bound method Instance.get_class of [24709.1, 54.7452, 1915.39 | 0]>
# <bound method Instance.get_class of [43053, 31.5269, 488.937 | 0]>
# <bound method Instance.get_class of [25003.9, 53.4116, 2183.71 | 0]>
# <bound method Instance.get_class of [46696.9, 34.1998, 4732.5 | 0]>
# <bound method Instance.get_class of [50112.5, 41.3046, 5067.03 | 0]>
# <bound method Instance.get_class of [43265.9, 44.7433, 6194.07 | 0]>
# <bound method Instance.get_class of [67802.7, 49.038, 13443.5 | 0]>
# <bound method Instance.get_class of [55408.7, 43.3228, 10300.3 | 0]>
# <bound method Instance.get_class of [67048.9, 55.053, 10839.9 | 0]>
# <bound method Instance.get_class of [40262.6, 51.7989, 6535.85 | 0]>
# <bound method Instance.get_class of [46427.5, 61.8465, 5671.45 | 0]>
# <bound method Instance.get_class of [46911.2, 23.431, 4263.85 | 0]>
# <bound method Instance.get_class of [57359.6, 34.7953, 10011.4 | 1]>
# <bound method Instance.get_class of [34569.3, 63.6407, 6254.53 | 0]>
# <bound method Instance.get_class of [52797.4, 21.127, 1080.42 | 0]>
# <bound method Instance.get_class of [56630.4, 57.9732, 8442.89 | 0]>
# <bound method Instance.get_class of [45245.7, 35.8244, 1974.01 | 0]>
# <bound method Instance.get_class of [20803.6, 61.8923, 758.435 | 0]>
# <bound method Instance.get_class of [57717.6, 48.7978, 3153.22 | 0]>
# <bound method Instance.get_class of [20647.9, 20.3216, 725.457 | 0]>
# <bound method Instance.get_class of [59046.5, 36.8271, 8237.05 | 0]>
# <bound method Instance.get_class of [62662.3, 25.2989, 1965.92 | 0]>
# <bound method Instance.get_class of [33614.5, 46.4731, 4837.79 | 0]>
# <bound method Instance.get_class of [48765.1, 50.0704, 5183.86 | 0]>
# <bound method Instance.get_class of [57240.8, 41.5714, 313.628 | 0]>
# <bound method Instance.get_class of [49973.7, 43.9186, 363.9 | 0]>
# <bound method Instance.get_class of [41255.9, 45.5833, 5296.91 | 0]>
# <bound method Instance.get_class of [61129.7, 35.1092, 11302.8 | 0]>
# <bound method Instance.get_class of [48938.6, 59.7079, 3028.83 | 0]>
# <bound method Instance.get_class of [68648.2, 27.92, 9425.71 | 1]>
# <bound method Instance.get_class of [41250.8, 39.0782, 7651.58 | 0]>
# <bound method Instance.get_class of [22415.7, 40.6873, 4371.72 | 0]>
# <bound method Instance.get_class of [24112.5, 35.9713, 3285.5 | 0]>
# <bound method Instance.get_class of [41692.6, 62.1212, 1708.71 | 0]>
# <bound method Instance.get_class of [23516.7, 27.3627, 559.905 | 0]>
# <bound method Instance.get_class of [53812.2, 44.9192, 3245.04 | 0]>
# <bound method Instance.get_class of [29750.3, 45.5445, 3627.99 | 0]>
# <bound method Instance.get_class of [22633.7, 37.5969, 553.521 | 0]>
# <bound method Instance.get_class of [28713.8, 54.7008, 1936.81 | 0]>
# <bound method Instance.get_class of [63321.9, 19.4879, 8092.98 | 1]>
# <bound method Instance.get_class of [35276.6, 28.5721, 6820.32 | 1]>
# <bound method Instance.get_class of [35914.6, 60.8051, 520.996 | 0]>
# <bound method Instance.get_class of [31568.1, 63.864, 5067.41 | 0]>
# <bound method Instance.get_class of [39934.1, 31.608, 184.744 | 0]>
# <bound method Instance.get_class of [48614.8, 61.3013, 5984.95 | 0]>
# <bound method Instance.get_class of [29838.1, 25.8951, 5913.65 | 1]>
# <bound method Instance.get_class of [57745.4, 36.7296, 5540.46 | 0]>
# <bound method Instance.get_class of [44447.5, 32.7181, 2714.4 | 0]>
# <bound method Instance.get_class of [51768, 30.5445, 6632.04 | 1]>
# <bound method Instance.get_class of [34891.1, 55.0489, 6152.31 | 0]>
# <bound method Instance.get_class of [45382.8, 42.5163, 2742.45 | 0]>
# <bound method Instance.get_class of [40719.5, 22.9269, 6415.09 | 1]>
# <bound method Instance.get_class of [55145.8, 57.8825, 8968.68 | 0]>
# <bound method Instance.get_class of [48752.4, 30.7634, 8934.79 | 1]>
# <bound method Instance.get_class of [55763.4, 30.5854, 7913.84 | 1]>
# <bound method Instance.get_class of [36431.2, 46.4528, 6783.36 | 0]>
# <bound method Instance.get_class of [40522.8, 63.8871, 7720.78 | 0]>
# <bound method Instance.get_class of [42465.7, 58.0166, 7314.98 | 0]>
# <bound method Instance.get_class of [38561.9, 45.8798, 4831.11 | 0]>
# <bound method Instance.get_class of [54957.4, 59.5064, 6976.46 | 0]>
# <bound method Instance.get_class of [24822.1, 29.0204, 2361.17 | 0]>
# <bound method Instance.get_class of [25252.5, 23.7883, 434.867 | 0]>
# <bound method Instance.get_class of [25671.7, 18.7465, 2272.15 | 0]>
# <bound method Instance.get_class of [60672.1, 43.0559, 6279.69 | 0]>
# <bound method Instance.get_class of [60729.9, 40.7735, 5006.85 | 0]>
# <bound method Instance.get_class of [40240.7, 26.959, 7498.63 | 1]>
# <bound method Instance.get_class of [57513.8, 33.092, 6921.49 | 1]>
# <bound method Instance.get_class of [64287.4, 45.8839, 6301.59 | 0]>
# <bound method Instance.get_class of [48428, 33.9324, 7718.48 | 1]>
# <bound method Instance.get_class of [55313.8, 25.2126, 9733.11 | 1]>
# <bound method Instance.get_class of [27045.4, 50.2212, 2503.79 | 0]>
# <bound method Instance.get_class of [58216.1, 27.4045, 9581.83 | 1]>
# <bound method Instance.get_class of [34723, 22.2234, 4073.41 | 0]>
# <bound method Instance.get_class of [58503.8, 42.3725, 7050.43 | 0]>
# <bound method Instance.get_class of [55299.8, 62.1931, 8052.38 | 0]>
# <bound method Instance.get_class of [49501.9, 50.7881, 2226.82 | 0]>
# <bound method Instance.get_class of [61765.7, 59.9559, 3649.64 | 0]>
# <bound method Instance.get_class of [48431, 18.5081, 6069.65 | 1]>
# <bound method Instance.get_class of [66367, 41.5762, 465.012 | 0]>
# <bound method Instance.get_class of [55320.8, 29.4172, 5990.72 | 0]>
# <bound method Instance.get_class of [48774.3, 62.8408, 3728.48 | 0]>
# <bound method Instance.get_class of [61680, 24.1914, 3060.03 | 0]>
# <bound method Instance.get_class of [61485.2, 60.1882, 3211.67 | 0]>
# <bound method Instance.get_class of [24402.4, 52.0276, 101.219 | 0]>
# <bound method Instance.get_class of [21258.9, 54.2246, 706.62 | 0]>
# <bound method Instance.get_class of [48763.7, 28.0603, 8172.05 | 1]>
# <bound method Instance.get_class of [24406.9, 37.9053, 1733.4 | 0]>
# <bound method Instance.get_class of [61693.6, 25.6842, 1568.86 | 0]>
# <bound method Instance.get_class of [22748, 26.9407, 108.63 | 0]>
# <bound method Instance.get_class of [21479.9, 24.3143, 1098.07 | 0]>
# <bound method Instance.get_class of [51286.7, 45.8598, 1134.23 | 0]>
# <bound method Instance.get_class of [27153.7, 48.818, 3177.52 | 0]>
# <bound method Instance.get_class of [36370.5, 39.6708, 2855.22 | 0]>
# <bound method Instance.get_class of [32400.5, 61.6792, 3591.8 | 0]>
# <bound method Instance.get_class of [60434.2, 63.2186, 2474.25 | 0]>
# <bound method Instance.get_class of [57303.5, 52.1554, 10491.6 | 0]>
# <bound method Instance.get_class of [42994.7, 36.4256, 4453.82 | 0]>
# <bound method Instance.get_class of [68339.8, 23.3653, 2505.87 | 0]>
# <bound method Instance.get_class of [49292.3, 20.6223, 967.135 | 0]>
# <bound method Instance.get_class of [57802.4, 43.0417, 6796.59 | 0]>
# <bound method Instance.get_class of [50779.4, 39.4359, 6859.84 | 0]>
# <bound method Instance.get_class of [35994, 53.939, 93.8958 | 0]>
# <bound method Instance.get_class of [21771.1, 33.6878, 350.446 | 0]>
# <bound method Instance.get_class of [61414.8, 56.8892, 9743.61 | 0]>
# <bound method Instance.get_class of [35784.7, 46.5479, 110.203 | 0]>
# <bound method Instance.get_class of [24791.2, 39.6433, 4844.68 | 0]>
# <bound method Instance.get_class of [49048.8, 52.0518, 6363.11 | 0]>
# <bound method Instance.get_class of [69852.1, 62.2023, 9246.27 | 0]>
# <bound method Instance.get_class of [21217.7, 21.3657, 2690.77 | 1]>
# <bound method Instance.get_class of [48031.1, 43.6702, 7826.33 | 0]>
# <bound method Instance.get_class of [64072.3, 61.1584, 2426.01 | 0]>
# <bound method Instance.get_class of [56689.5, 41.0034, 5740.59 | 0]>
# <bound method Instance.get_class of [45769.3, 55.8272, 8236.48 | 0]>
# <bound method Instance.get_class of [35020.5, 24.9919, 6832.8 | 1]>
# <bound method Instance.get_class of [56751.9, 59.2044, 7877.33 | 0]>
# <bound method Instance.get_class of [27363.6, 44.3864, 3215.26 | 0]>
# <bound method Instance.get_class of [48455.7, 27.4763, 1780.51 | 0]>
# <bound method Instance.get_class of [21424.1, 36.9184, 1795.22 | 0]>
# <bound method Instance.get_class of [69992.3, 41.7712, 52.8722 | 0]>
# <bound method Instance.get_class of [68110.2, 32.1716, 11029.7 | 1]>
# <bound method Instance.get_class of [48015.6, 28.2418, 54.0082 | 0]>
# <bound method Instance.get_class of [23102.2, 35.7617, 1779.57 | 0]>
# <bound method Instance.get_class of [46134.9, 54.8654, 8716.61 | 0]>
# <bound method Instance.get_class of [48548, 56.6415, 1940.87 | 0]>
# <bound method Instance.get_class of [26095, 58.1021, 5143.49 | 0]>
# <bound method Instance.get_class of [64057.8, 59.8584, 5774.28 | 0]>
# <bound method Instance.get_class of [24454.2, 52.3909, 864.969 | 0]>
# <bound method Instance.get_class of [40506.9, 52.2415, 5961.53 | 0]>
# <bound method Instance.get_class of [43421, 27.2174, 4705.76 | 0]>
# <bound method Instance.get_class of [55881.5, 33.3067, 8383.07 | 1]>
# <bound method Instance.get_class of [45917.6, 45.1571, 8253.27 | 0]>
# <bound method Instance.get_class of [52901.9, 60.2614, 729.377 | 0]>
# <bound method Instance.get_class of [41183.8, 56.0324, 7606.99 | 0]>
# <bound method Instance.get_class of [25379.9, 24.9291, 4693.11 | 1]>
# <bound method Instance.get_class of [27514.1, 36.2787, 192.145 | 0]>
# <bound method Instance.get_class of [44241.3, 19.9825, 8733.18 | 1]>
# <bound method Instance.get_class of [29076.3, 41.2225, 286.264 | 0]>
# <bound method Instance.get_class of [60536.9, 32.3262, 3132.55 | 0]>
# <bound method Instance.get_class of [47882, 38.0998, 5575.64 | 0]>
# <bound method Instance.get_class of [49144.4, 51.8938, 1633.04 | 0]>
# <bound method Instance.get_class of [33707.8, 59.9176, 321.579 | 0]>
# <bound method Instance.get_class of [46442.3, 28.846, 1484.56 | 0]>
# <bound method Instance.get_class of [25603, 28.4464, 2214.92 | 0]>
# <bound method Instance.get_class of [61236.4, 36.0017, 6562.9 | 0]>
# <bound method Instance.get_class of [48187.3, 55.533, 2003.41 | 0]>
# <bound method Instance.get_class of [29933.2, 18.659, 5953.52 | 1]>
# <bound method Instance.get_class of [41027.9, 44.7719, 4369.22 | 0]>
# <bound method Instance.get_class of [49990.7, 45.5428, 1896.75 | 0]>
# <bound method Instance.get_class of [59792.5, 24.1875, 660.241 | 0]>
# <bound method Instance.get_class of [35879.5, 41.0729, 5335.4 | 0]>
# <bound method Instance.get_class of [29102.2, 27.1292, 1890.45 | 0]>
# <bound method Instance.get_class of [30047.8, 51.0773, 5768.74 | 0]>
# <bound method Instance.get_class of [59299.2, 36.9843, 4944.06 | 0]>
# <bound method Instance.get_class of [64484, 33.0994, 1391.6 | 0]>
# <bound method Instance.get_class of [36352.4, 43.7189, 6239.25 | 0]>
# <bound method Instance.get_class of [66034.8, 60.7263, 3913.78 | 0]>
# <bound method Instance.get_class of [51650.3, 40.1051, 3743 | 0]>
# <bound method Instance.get_class of [31898.2, 41.3172, 2015.18 | 0]>
# <bound method Instance.get_class of [58780.2, 18.7017, 5029.71 | 0]>
# <bound method Instance.get_class of [67754.1, 42.9808, 2989.95 | 0]>
# <bound method Instance.get_class of [48500.3, 61.3048, 7054.61 | 0]>
# <bound method Instance.get_class of [55704.8, 48.5166, 5594.33 | 0]>
# <bound method Instance.get_class of [50459, 52.3146, 9852.89 | 0]>
# <bound method Instance.get_class of [48263, 28.5496, 7798.79 | 1]>
# <bound method Instance.get_class of [38755.2, 56.3554, 4244.5 | 0]>
# <bound method Instance.get_class of [68131.7, 57.4053, 7813.24 | 0]>
# <bound method Instance.get_class of [28991.4, 37.1652, 1249.35 | 0]>
# <bound method Instance.get_class of [35108.6, 40.7434, 4002.99 | 0]>
# <bound method Instance.get_class of [28858.6, 23.6946, 3764.82 | 1]>
# <bound method Instance.get_class of [22800.8, 28.1983, 3740.9 | 1]>
# <bound method Instance.get_class of [29573, 39.2305, 5006.25 | 0]>
# <bound method Instance.get_class of [21982, 34.9155, 4265.17 | 1]>
# <bound method Instance.get_class of [45576.8, 38.671, 4952.65 | 0]>
# <bound method Instance.get_class of [55068.7, 51.7574, 4852.77 | 0]>
# <bound method Instance.get_class of [56441, 43.207, 9043.76 | 0]>
# <bound method Instance.get_class of [68047.9, 47.6945, 4023.06 | 0]>
# <bound method Instance.get_class of [36275.7, 30.3082, 644.384 | 0]>
# <bound method Instance.get_class of [52389.4, 54.9693, 10398.8 | 0]>
# <bound method Instance.get_class of [23678.4, 47.4665, 1779.81 | 0]>
# <bound method Instance.get_class of [37707.6, 31.344, 268.291 | 0]>
# <bound method Instance.get_class of [57753.6, 54.2359, 5067.45 | 0]>
# <bound method Instance.get_class of [30530, 47.6044, 6046.84 | 0]>
# <bound method Instance.get_class of [44022.3, 31.1926, 1707.67 | 0]>
# <bound method Instance.get_class of [58533.9, 40.519, 7832.44 | 0]>
# <bound method Instance.get_class of [33702.5, 48.1484, 922.037 | 0]>
# <bound method Instance.get_class of [40236.9, 52.5808, 4354.31 | 0]>
# <bound method Instance.get_class of [62619.2, 43.9995, 3959.61 | 0]>
# <bound method Instance.get_class of [50738.4, 45.9932, 9719.56 | 0]>
# <bound method Instance.get_class of [64466.8, 33.3271, 8537.37 | 1]>
# <bound method Instance.get_class of [64636.4, 60.887, 2583.11 | 0]>
# <bound method Instance.get_class of [22371.5, 39.1422, 2291.86 | 0]>
# <bound method Instance.get_class of [67995, 38.6223, 7289.01 | 0]>
# <bound method Instance.get_class of [49640, 20.5424, 5760.86 | 0]>
# <bound method Instance.get_class of [42067.2, 24.2706, 4601.61 | 0]>
# <bound method Instance.get_class of [43662.1, 25.2526, 7269.6 | 1]>
# <bound method Instance.get_class of [34237.6, 34.1017, 2658.09 | 0]>
# <bound method Instance.get_class of [26300.4, 45.5394, 2317.39 | 0]>
# <bound method Instance.get_class of [30803.8, 23.2501, 623.024 | 0]>
# <bound method Instance.get_class of [54421.4, 26.8219, 3273.63 | 0]>
# <bound method Instance.get_class of [24254.7, 37.7516, 2225.28 | 0]>
# <bound method Instance.get_class of [59221, 48.5182, 1926.73 | 0]>
# <bound method Instance.get_class of [69516.1, 23.1621, 3503.18 | 0]>
# <bound method Instance.get_class of [44311.4, 28.0172, 5522.79 | 1]>
# <bound method Instance.get_class of [43756.1, 63.9718, 1622.72 | 0]>
# <bound method Instance.get_class of [69436.6, 56.1526, 7378.83 | 0]>

# %%
from collections import Counter
Counter(str(registro.get_class()) for registro in base_credit)

# Como a maioria dos registros sao 0 (pagam a divida), novas entradas de dados, por padrao, deverao ser classificadas como 0
# Out:
# Counter({'0': 1717, '1': 283})

# %%
1711/2000 # mesmo de CA

# este valor serve como referencia para se comparar com a acuracia de outros modelos de ML. Se a acuracia dos outros modelos for menor do que o encontrado no Majority Learner,
# eh desprezar o modelo e ficar com o indicado neste.
# Out:
# 0.8555
